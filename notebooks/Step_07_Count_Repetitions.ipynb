# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from DataTransformation import LowPassFilter
from scipy.signal import argrelextrema
from sklearn.metrics import mean_absolute_error
# Out:
# <ipython-input-1-8b905338f85e>:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
pd.options.mode.chained_assignment = None

# %%
plt.style.use("fivethirtyeight")
plt.rcParams["figure.figsize"] = (20, 5)
plt.rcParams["figure.dpi"] = 100
plt.rcParams["lines.linewidth"] = 2

# %%
df = pd.read_pickle("../../data/interim/01_data_processed.pkl")

# %%
df = df[df["label"] != "rest"]

# %%
acc_r = np.sqrt((df["acc_x"] ** 2) + (df["acc_y"] ** 2) + (df["acc_z"] ** 2))
gyr_r = np.sqrt((df["gyr_x"] ** 2) + (df["gyr_y"] ** 2) + (df["gyr_z"] ** 2))

# %%
df["acc_r"] = acc_r
df["gyr_r"] = gyr_r

# %%
bench_df = df[df["label"] == "bench"]
squat_df = df[df["label"] == "squat"]
row_df = df[df["label"] == "row"]
ohp_df = df[df["label"] == "ohp"]
bench_df = df[df["label"] == "bench"]
dead_df = df[df["label"] == "dead"]

# %%
plot_df = bench_df

# %%
plot_df[plot_df["set"] == plot_df["set"].unique()[0]]["acc_x"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
plot_df[plot_df["set"] == plot_df["set"].unique()[0]]["acc_y"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
plot_df[plot_df["set"] == plot_df["set"].unique()[0]]["acc_z"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
plot_df[plot_df["set"] == plot_df["set"].unique()[0]]["acc_r"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
plot_df[plot_df["set"] == plot_df["set"].unique()[0]]["gyr_x"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
plot_df[plot_df["set"] == plot_df["set"].unique()[0]]["gyr_y"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
plot_df[plot_df["set"] == plot_df["set"].unique()[0]]["gyr_z"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
plot_df[plot_df["set"] == plot_df["set"].unique()[0]]["gyr_r"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
fs = 1000 / 200

# %%
LowPass = LowPassFilter()

# %%
bench_set = bench_df[bench_df["set"] == bench_df["set"].unique()[0]]

# %%
squat_set = squat_df[squat_df["set"] == squat_df["set"].unique()[0]]

# %%
row_set = row_df[row_df["set"] == row_df["set"].unique()[0]]

# %%
ohp_set = ohp_df[ohp_df["set"] == ohp_df["set"].unique()[0]]

# %%
dead_set = dead_df[dead_df["set"] == dead_df["set"].unique()[0]]

# %%
bench_set["acc_r"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
column = "acc_r"

# %%
LowPass.low_pass_filter(
    bench_set, col=column, sampling_frequency=fs, cutoff_frequency=0.4, order=5
)[column + "_lowpass"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
LowPass.low_pass_filter(
    bench_set, col=column, sampling_frequency=fs, cutoff_frequency=0.9, order=5
)[column + "_lowpass"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
LowPass.low_pass_filter(
    bench_set, col=column, sampling_frequency=fs, cutoff_frequency=0.5, order=5
)[column + "_lowpass"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
LowPass.low_pass_filter(
    bench_set, col=column, sampling_frequency=fs, cutoff_frequency=0.4, order=5
)[column + "_lowpass"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
LowPass.low_pass_filter(
    bench_set, col=column, sampling_frequency=fs, cutoff_frequency=0.37, order=5
)[column + "_lowpass"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
LowPass.low_pass_filter(
    bench_set, col=column, sampling_frequency=fs, cutoff_frequency=0.57, order=5
)[column + "_lowpass"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
LowPass.low_pass_filter(
    bench_set, col=column, sampling_frequency=fs, cutoff_frequency=0.47, order=5
)[column + "_lowpass"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
LowPass.low_pass_filter(
    bench_set, col=column, sampling_frequency=fs, cutoff_frequency=0.43, order=5
)[column + "_lowpass"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
bench_set["acc_y"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
LowPass.low_pass_filter(
    bench_set, col=column, sampling_frequency=fs, cutoff_frequency=0.43, order=5
)[column + "_lowpass"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
column = "acc_y"

# %%
LowPass.low_pass_filter(
    bench_set, col=column, sampling_frequency=fs, cutoff_frequency=0.43, order=5
)[column + "_lowpass"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
LowPass.low_pass_filter(
    bench_set, col=column, sampling_frequency=fs, cutoff_frequency=0.41, order=5
)[column + "_lowpass"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
LowPass.low_pass_filter(
    bench_set, col=column, sampling_frequency=fs, cutoff_frequency=0.4, order=5
)[column + "_lowpass"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
bench_set["acc_r"].plot()

column = "acc_r"
LowPass.low_pass_filter(
    bench_set, col=column, sampling_frequency=fs, cutoff_frequency=0.4, order=5
)[column + "_lowpass"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>

# %%
LowPass.low_pass_filter(
    bench_set, col=column, sampling_frequency=fs, cutoff_frequency=0.4, order=5
)[column + "_lowpass"].plot()
# Out:
# <Axes: xlabel='epoch (ms)'>
